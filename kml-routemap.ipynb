# %% [markdown]
# # Merge individual gpx tracks into a single styled kml file

# %% [markdown]
# ## imports

# %%
import gpxpy
import simplekml
from pathlib import Path

# %% [markdown]
# ## processing functions

# %%
def get_gpx(gpxpath, max_distance=5):
    """
        reads in all gpx files stored in folder gpxpath (Pathlib object)
        returns dict containing all routes (coordinates) and descriptions (route parameters)
        route coordinates are modified from raw coordinates to shrink filesize,
        the max allowed deviation from original route (in meter) is specified by max_distance
        route parameters length and uphill are calculated from raw route for best accuracy and
        appended as emojified description tag
    """
    
    with open(gpxpath, 'r') as gpx_file:
        gpx = gpxpy.parse(gpx_file)
    

    uphill = gpx.get_uphill_downhill()[0]
    length = gpx.length_2d()
    description = f'🚴🏽‍♀️🚴🏼‍♂️ {(length/1000.0):.0f} km <br> ⛰️⬆️ {uphill:.0f} m'
    print(description)
    
    gpx.simplify(max_distance=max_distance)
    coords = [(p.longitude, p.latitude) for p in gpx.tracks[0].segments[0].points]
    
    return {'coords':coords, 'description':description, 'uphill':uphill, 'length':length}

# %%
def generate_kml(gpxdict, kmlpath = 'merged_kml.kml'):
    """
        composes kml output from gpx tracks preprocessed by get_gmx and stored in gpxdict
    """
    
    kml = simplekml.Kml()
    kml.document.name = "Fahrrad"
    
    # define individual styles (color and thickness)
    ls1 = simplekml.Style()
    ls1.linestyle.color = simplekml.Color.red
    ls1.linestyle.width = 4
    
    ls2 = simplekml.Style()
    ls2.linestyle.color = simplekml.Color.blue
    ls2.linestyle.width = 4    
    
    # append individual gpx tracks, style according to tracknr
    for gpxname, gpxdata in gpxdict.items():
        
        line = kml.newlinestring(
            name=gpxname,
            tessellate=1,
            coords = gpxdata['coords'],
            description = gpxdata['description']
        )
        
        tracknr = int(gpxname.split(" ")[0])
        if (tracknr % 2) == 0:
            line.style = ls1
        else:
            line.style = ls2
            
    kml.save(kmlpath)

# %% [markdown]
# ## process tracks and generate kml

# %%
# get list of inputfiles as dict: simplified name (key) - filepath (value)
ifolder = Path('inputtracks')
flist = list(ifolder.glob('*.gpx'))
ifiles = {file.stem.split('_')[2] : file for file in flist}

# %%
# process each inputfile and store metadata and coordinates in gpxdict
gpxdict = {}

for gpxname, gpxpath in ifiles.items():
    print(gpxpath)
    gpxdict[gpxname] = get_gpx(gpxpath)
# Out:
# inputtracks\2022-08-13_892679520_00 Landsberg - Peiting.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 41 km <br> ⛰️⬆️ 262 m
# inputtracks\2022-08-15_892679405_01 Peiting - Bad Tölz.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 57 km <br> ⛰️⬆️ 433 m
# inputtracks\2022-08-16_892679042_02 Bad Tölz - Chiemsee.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 84 km <br> ⛰️⬆️ 771 m
# inputtracks\2022-08-17_000000000_03 Chiemsee - Salzburg.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 83 km <br> ⛰️⬆️ 411 m
# inputtracks\2022-08-18_892673818_04 Salzburg - Sankt Johann im Pongau.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 59 km <br> ⛰️⬆️ 496 m
# inputtracks\2022-08-19_893481985_05 Sankt Johann im Pongau - Bad Gastein.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 42 km <br> ⛰️⬆️ 694 m
# inputtracks\2022-08-20_894855802_06 Bad Gastein - Spittal an der Drau.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 63 km <br> ⛰️⬆️ 419 m
# inputtracks\2022-08-21_915503776_07 Spittal an der Drau - Villach.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 40 km <br> ⛰️⬆️ 78 m
# inputtracks\2022-08-22_898371044_08 Villach - Bovec.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 63 km <br> ⛰️⬆️ 813 m
# inputtracks\2022-08-23_902459171_09 Bovec - Cividale del Friuli.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 53 km <br> ⛰️⬆️ 370 m
# inputtracks\2022-08-25_902456188_10 Cividale del Friuli - Razdrto.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 80 km <br> ⛰️⬆️ 833 m
# inputtracks\2022-08-26_905233819_11 Razdrto - Zerovnica.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 40 km <br> ⛰️⬆️ 371 m
# inputtracks\2022-08-27_905233696_12 Zerovnica - Zuzemberg.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 66 km <br> ⛰️⬆️ 704 m
# inputtracks\2022-08-28_906485101_13 Zuzemberg - Vinica.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 61 km <br> ⛰️⬆️ 704 m
# inputtracks\2022-08-29_907704585_14 Vinica - Slunj.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 67 km <br> ⛰️⬆️ 588 m
# inputtracks\2022-08-31_910992194_15 Slunj - Bihac.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 62 km <br> ⛰️⬆️ 420 m
# inputtracks\2022-09-01_910991536_16 Bihac - Kulen Vakuf.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 34 km <br> ⛰️⬆️ 559 m
# inputtracks\2022-09-02_912146786_17 Kulen Vakuf - Podovi.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 47 km <br> ⛰️⬆️ 787 m
# inputtracks\2022-09-03_913895968_18 Podovi - Jajce.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 119 km <br> ⛰️⬆️ 1188 m
# inputtracks\2022-09-05_916580668_19 Jajce - Kupres.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 72 km <br> ⛰️⬆️ 1109 m
# inputtracks\2022-09-06_917572048_20 Kupres - Blidinje.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 70 km <br> ⛰️⬆️ 613 m
# inputtracks\2022-09-07_918645084_21 Blidinje - Mostar.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 67 km <br> ⛰️⬆️ 602 m
# inputtracks\2022-09-10_923312590_22 Mostar - Hutovo.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 79 km <br> ⛰️⬆️ 531 m
# inputtracks\2022-09-11_923312767_23 Hutovo - Trebinje.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 89 km <br> ⛰️⬆️ 335 m
# inputtracks\2022-09-12_924483216_24 Trebinje - Niksic.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 63 km <br> ⛰️⬆️ 867 m
# inputtracks\2022-09-13_925245896_25 Niksic - Savnik.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 60 km <br> ⛰️⬆️ 1274 m
# inputtracks\2022-09-14_926015923_26 Savnik - Zabljak.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 49 km <br> ⛰️⬆️ 906 m
# inputtracks\2022-09-15_926909715_27 Prevoj Sedlo.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 29 km <br> ⛰️⬆️ 538 m
# inputtracks\2022-09-16_929048061_28 Zabljak - Mojkovac.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 72 km <br> ⛰️⬆️ 563 m
# inputtracks\2022-09-17_929047978_29 Mojkovac - Petnjica.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 65 km <br> ⛰️⬆️ 669 m
# inputtracks\2022-09-18_929855299_30 Petnjica - Peja.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 77 km <br> ⛰️⬆️ 1370 m
# inputtracks\2022-09-20_931304495_31 Peja - Gjakova.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 41 km <br> ⛰️⬆️ 191 m
# inputtracks\2022-09-21_932312924_32 Gjakova - Prizren.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 42 km <br> ⛰️⬆️ 238 m
# inputtracks\2022-09-22_933286314_33 Prizren - Prevalla.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 28 km <br> ⛰️⬆️ 1105 m
# inputtracks\2022-09-23_934739536_34 Prevalla - Vratnitsa.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 59 km <br> ⛰️⬆️ 663 m
# inputtracks\2022-09-23_935397787_35 Vratnitsa - Skopje.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 43 km <br> ⛰️⬆️ 102 m
# inputtracks\2022-09-25_937983849_36 Skopje - Gradsko.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 77 km <br> ⛰️⬆️ 488 m
# inputtracks\2022-09-27_937983925_37 Gradsko - Demir Kapija.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 42 km <br> ⛰️⬆️ 183 m
# inputtracks\2022-09-28_938487331_38 Demir Kapija - Dojran.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 64 km <br> ⛰️⬆️ 352 m
# inputtracks\2022-09-29_939587258_39 Dojran - Thessaloniki.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 86 km <br> ⛰️⬆️ 479 m
# inputtracks\2022-10-08_949896736_40 Datça - Marmaris.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 54 km <br> ⛰️⬆️ 787 m
# inputtracks\2022-10-09_949897008_41 Marmaris - Köyceğiz.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 85 km <br> ⛰️⬆️ 784 m
# inputtracks\2022-10-10_949897981_42 Köyceğiz - Fethiye.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 68 km <br> ⛰️⬆️ 879 m
# inputtracks\2022-10-11_951351084_43 Fethiye - Kalkan.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 78 km <br> ⛰️⬆️ 895 m
# inputtracks\2022-10-12_951351362_44 Kalkan - Kas.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 43 km <br> ⛰️⬆️ 761 m
# inputtracks\2022-10-13_952079043_45 Kas - Demre.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 36 km <br> ⛰️⬆️ 781 m
# inputtracks\2022-10-14_954161328_46 Demre - Karaöz.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 68 km <br> ⛰️⬆️ 259 m
# inputtracks\2022-10-15_954161202_47 Karaöz - Antalya.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 92 km <br> ⛰️⬆️ 1155 m
# inputtracks\2022-10-16_955681640_48 Antalya.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 16 km <br> ⛰️⬆️ 94 m
# inputtracks\2022-10-18_959711722_49 Antalya - Sagirin.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 78 km <br> ⛰️⬆️ 339 m
# inputtracks\2022-10-19_959712059_50 Sagirin - Yesilbag.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 52 km <br> ⛰️⬆️ 1125 m
# inputtracks\2022-10-20_959712826_51 Yesilbag - Beysehir.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 69 km <br> ⛰️⬆️ 1255 m
# inputtracks\2022-10-21_959713392_52 Beysehir - Konya.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 96 km <br> ⛰️⬆️ 959 m
# inputtracks\2022-10-23_961083728_53 Konya - Tuz Gölü.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 122 km <br> ⛰️⬆️ 204 m
# inputtracks\2022-10-24_963245606_54 Tuz Gölü - Sultanhani.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 38 km <br> ⛰️⬆️ 76 m
# inputtracks\2022-10-25_963245912_55 Sultanhani - Ihlara.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 84 km <br> ⛰️⬆️ 590 m
# inputtracks\2022-10-26_963246538_56 Ihlara - Derinkuyu.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 61 km <br> ⛰️⬆️ 561 m
# inputtracks\2022-10-27_964828927_57 Derinkuyu - Göreme.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 43 km <br> ⛰️⬆️ 370 m
# inputtracks\2022-10-28_964829013_58 Göreme.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 10 km <br> ⛰️⬆️ 146 m
# inputtracks\2022-10-29_966109836_59 Love & Red Valley.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 18 km <br> ⛰️⬆️ 328 m
# inputtracks\2022-10-30_970295755_60 Göreme - Incesu.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 41 km <br> ⛰️⬆️ 700 m
# inputtracks\2022-10-31_970296110_61 Incesu - Kayseri.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 51 km <br> ⛰️⬆️ 659 m
# inputtracks\2022-11-02_971569049_62 Diyarbakir - Siverek.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 85 km <br> ⛰️⬆️ 788 m
# inputtracks\2022-11-03_971569138_63 Siverek - Urfa.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 104 km <br> ⛰️⬆️ 668 m
# inputtracks\2022-11-05_974221641_64 Urfa - Birecik.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 84 km <br> ⛰️⬆️ 814 m
# inputtracks\2022-11-10_977184866_65 Girne - Alaminos.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 89 km <br> ⛰️⬆️ 844 m
# inputtracks\2022-11-11_977184929_66 Alaminos - Limassol.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 51 km <br> ⛰️⬆️ 249 m
# inputtracks\2022-11-14_982428930_67 Haifa - Atlit.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 26 km <br> ⛰️⬆️ 126 m
# inputtracks\2022-11-15_982428935_68 Atlit - Netanya.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 76 km <br> ⛰️⬆️ 295 m
# inputtracks\2022-11-16_982428940_69 Netanya - Tel Aviv.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 39 km <br> ⛰️⬆️ 172 m
# inputtracks\2022-11-17_982428947_70 Tel Aviv - Eshtaol.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 74 km <br> ⛰️⬆️ 532 m
# inputtracks\2022-11-18_982428955_71 Eshtaol - Jerusalem.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 47 km <br> ⛰️⬆️ 1010 m
# inputtracks\2022-11-20_982803592_72 Jerusalem - Totes Meer.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 72 km <br> ⛰️⬆️ 620 m
# inputtracks\2022-11-21_985206001_73 Totes Meer - En Bokek.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 59 km <br> ⛰️⬆️ 485 m
# inputtracks\2022-11-22_985206061_74 En Bokek - Zofar.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 89 km <br> ⛰️⬆️ 651 m
# inputtracks\2022-11-23_985206120_75 Zofar - Hai-bar Yotvata.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 94 km <br> ⛰️⬆️ 436 m
# inputtracks\2022-11-24_985206156_76 Hai-bar Yotvata - Eilat.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 51 km <br> ⛰️⬆️ 314 m
# inputtracks\2022-11-25_985206203_77 Eilat - Aqaba.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 25 km <br> ⛰️⬆️ 199 m
# inputtracks\2022-11-26_987264036_78 Aqaba - Wadi Rum.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 69 km <br> ⛰️⬆️ 930 m
# inputtracks\2022-11-27_987264087_79 Wadi Rum.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 15 km <br> ⛰️⬆️ 128 m
# inputtracks\2022-11-28_987264140_80 Wadi Rum - Rajif.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 55 km <br> ⛰️⬆️ 1065 m
# inputtracks\2022-11-29_987270533_81 Rajif - Wadi Musa.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 25 km <br> ⛰️⬆️ 249 m
# inputtracks\2022-12-01_989779020_82 Wadi Musa - Dana.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 55 km <br> ⛰️⬆️ 740 m
# inputtracks\2022-12-02_989779051_83 Dana Tour.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 25 km <br> ⛰️⬆️ 563 m
# inputtracks\2022-12-03_989779092_84 Dana - Safi.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 69 km <br> ⛰️⬆️ 522 m
# inputtracks\2022-12-04_989779123_85 Dana - Totes Meer.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 71 km <br> ⛰️⬆️ 638 m
# inputtracks\2022-12-05_990011415_86 Totes Meer - Peace Wadi.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 43 km <br> ⛰️⬆️ 304 m
# inputtracks\2022-12-06_990463537_87 Peace Wadi - Eco Park.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 79 km <br> ⛰️⬆️ 476 m
# inputtracks\2022-12-07_991701423_88 Eco Park - See Genezareth.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 49 km <br> ⛰️⬆️ 328 m
# inputtracks\2022-12-08_991701490_89 See Genezareth - Meron.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 49 km <br> ⛰️⬆️ 1089 m
# inputtracks\2022-12-09_991703468_90 Meron - Liman.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 51 km <br> ⛰️⬆️ 530 m
# inputtracks\2022-12-10_992171417_91 Liman - Haifa.gpx
# 🚴🏽‍♀️🚴🏼‍♂️ 48 km <br> ⛰️⬆️ 107 m

# %%
# compose stylized kml from gpxdict
generate_kml(gpxdict)
